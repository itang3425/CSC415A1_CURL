# %%
# !git clone https://github.com/MishaLaskin/curl.git
# Out:
# Cloning into 'curl'...
# remote: Enumerating objects: 293, done.
# remote: Counting objects: 100% (72/72), done.
# remote: Compressing objects: 100% (11/11), done.
# remote: Total 293 (delta 62), reused 61 (delta 61), pack-reused 221 (from 1)
# Receiving objects: 100% (293/293), 58.16 KiB | 1.14 MiB/s, done.
# Resolving deltas: 100% (137/137), done.

# %%
# %cd /content/curl
# Out:
# /content/curl

# %%
# Source - https://stackoverflow.com/a/75239829
# Posted by merv
# Retrieved 2026-02-12, License - CC BY-SA 4.0

# !pip install -q condacolab
import condacolab
condacolab.install() # expect a kernel restart
# Out:
# ✨🍰✨ Everything looks OK!

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !rm -rf /usr/local/envs/curl_new

# %%
# !mamba env create -f /content/drive/MyDrive/curl_new_env_export.yml
# Out:
# Channels:
#  - pytorch
#  - nvidia
#  - conda-forge
# Platform: linux-64
# done
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#     current version: 24.11.2
#     latest version: 26.1.0
#
# Please update conda by running
#
#     $ conda update -n base -c conda-forge conda
#
#
#
# ...
# pytorch-2.5.1        | 1.35 GB   | :   0% 0/1 [00:00<?, ?it/s]
# libcublas-12.1.0.26  | 329.0 MB  | :   0% 0/1 [00:00<?, ?it/s]
#
# torchtriton-3.1.0    | 233.5 MB  | :   0% 0/1 [00:00<?, ?it/s]
#
#
# libcusparse-12.0.2.5 | 163.0 MB  | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
# mkl-2023.2.0         | 156.2 MB  | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
# libnpp-12.0.2.50     | 139.8 MB  | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
# libcufft-11.0.2.4    | 102.9 MB  | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
# libcusolver-11.4.4.5 | 98.3 MB   | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
# pillow-10.0.0        | 44.5 MB   | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
# ...

# %%
# !/usr/local/envs/curl_new/bin/pip install "pip<24" "setuptools<65" "wheel<0.38"
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 43.1 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 24.2 MB/s  0:00:00
# ...
#   Attempting uninstall: wheel
#     Found existing installation: wheel 0.46.3
#     Uninstalling wheel-0.46.3:
#       Successfully uninstalled wheel-0.46.3
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 82.0.0
#     Uninstalling setuptools-82.0.0:
#       Successfully uninstalled setuptools-82.0.0
#   Attempting uninstall: pip
#     Found existing installation: pip 26.0.1
#     Uninstalling pip-26.0.1:
#       Successfully uninstalled pip-26.0.1
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3/3 [pip]
# ...

# %%
# !/usr/local/envs/curl_new/bin/pip install gym==0.19.0 --no-build-isolation
# Out:
# ...
#   Using cached gym-0.19.0.tar.gz (1.6 MB)
#   Preparing metadata (setup.py) ... done
# ...
#   Using cached cloudpickle-1.6.0-py3-none-any.whl.metadata (4.3 kB)
# ...
#   Created wheel for gym: filename=gym-0.19.0-py3-none-any.whl size=1663092 sha256=132312bcd318c7a47a99a9cdd4fab2f7f8b476ac061f8230fb1b2174af822915
#   Stored in directory: /root/.cache/pip/wheels/c8/24/9d/db9869e09d1fbf12a10ce64362d9f161f09bdb5651e44317fe
# Successfully built gym
# ...

# %%
# !/usr/local/envs/curl_new/bin/pip install git+https://github.com/1nadequacy/dmc2gym.git
# Out:
# ...
#   Cloning https://github.com/1nadequacy/dmc2gym.git to /tmp/pip-req-build-s_2g_dfn
#   Running command git clone --filter=blob:none --quiet https://github.com/1nadequacy/dmc2gym.git /tmp/pip-req-build-s_2g_dfn
#   Resolved https://github.com/1nadequacy/dmc2gym.git to commit 06f7e335d988b17145947be9f6a76f557d0efe81
#   Preparing metadata (setup.py) ... done
# ...
#   Using cached dm_env-1.6-py3-none-any.whl.metadata (966 bytes)
# ...
#   Using cached dm_tree-0.1.9-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.2 kB)
# ...
#   Using cached glfw-2.10.0-py2.py27.py3.py30.py31.py32.py33.py34.py35.py36.py37.py38.py39.py310.py311.py312.py313.py314-none-manylinux_2_28_x86_64.whl.metadata (5.4 kB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.4/42.4 kB 1.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.7/57.7 kB 5.8 MB/s eta 0:00:00
# ...
#   Using cached attrs-25.4.0-py3-none-any.whl.metadata (10 kB)
# ...
#   Using cached etils-1.13.0-py3-none-any.whl.metadata (6.5 kB)
# ...

# %%
# !/usr/local/envs/curl_new/bin/python -V
# Out:
# Python 3.10.19

# %%
# !/usr/local/envs/curl_new/bin/python -c "import gym; print(gym.__version__)"
# Out:
# 0.19.0

# %%
# !/usr/local/envs/curl_new/bin/python -m pip install -r /content/drive/MyDrive/CURL_pip_reqs.txt
# Out:
# ...
#   Cloning https://github.com/1nadequacy/dmc2gym.git to /tmp/pip-req-build-w43wxin4
#   Running command git clone --filter=blob:none --quiet https://github.com/1nadequacy/dmc2gym.git /tmp/pip-req-build-w43wxin4
#   Resolved https://github.com/1nadequacy/dmc2gym.git to commit 06f7e335d988b17145947be9f6a76f557d0efe81
#   Preparing metadata (setup.py) ... done
# ...
#   Using cached annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# ...
#   Using cached click-8.3.1-py3-none-any.whl.metadata (2.6 kB)
# ...
#   Using cached dm_control-1.0.36-py3-none-any.whl.metadata (1.5 kB)
# ...
#   Using cached gitdb-4.0.12-py3-none-any.whl.metadata (1.2 kB)
# ...
#   Using cached gitpython-3.1.46-py3-none-any.whl.metadata (13 kB)
# ...
#   Using cached grpcio-1.78.0-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (3.8 kB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.0/42.0 kB 2.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.6/90.6 kB 7.0 MB/s eta 0:00:00
# ...

# %%
# !apt-get update -qq
# !apt-get install -y -qq libgl1-mesa-dri libgl1-mesa-glx libegl1-mesa mesa-utils
# Out:
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Selecting previously unselected package libegl1-mesa:amd64.
# (Reading database ... 121852 files and directories currently installed.)
# Preparing to unpack .../libegl1-mesa_23.0.4-0ubuntu1~22.04.1_amd64.deb ...
# Unpacking libegl1-mesa:amd64 (23.0.4-0ubuntu1~22.04.1) ...
# Selecting previously unselected package mesa-utils-bin:amd64.
# Preparing to unpack .../mesa-utils-bin_8.4.0-1ubuntu1_amd64.deb ...
# Unpacking mesa-utils-bin:amd64 (8.4.0-1ubuntu1) ...
# Selecting previously unselected package mesa-utils.
# Preparing to unpack .../mesa-utils_8.4.0-1ubuntu1_amd64.deb ...
# Unpacking mesa-utils (8.4.0-1ubuntu1) ...
# Setting up libegl1-mesa:amd64 (23.0.4-0ubuntu1~22.04.1) ...
# Setting up mesa-utils-bin:amd64 (8.4.0-1ubuntu1) ...
# Setting up mesa-utils (8.4.0-1ubuntu1) ...
# ...

# %%
import os
os.environ["MUJOCO_GL"] = "egl"           # headless GPU rendering
os.environ["PYOPENGL_PLATFORM"] = "egl"   # helps PyOpenGL pick EGL

# %%
# !mkdir /content/drive/MyDrive/curl_runs_detached

# %%
# !CUDA_VISIBLE_DEVICES=0 MUJOCO_GL=egl PYOPENGL_PLATFORM=egl \
  /usr/local/envs/curl_new/bin/python train.py \
  --domain_name cartpole \
  --task_name swingup \
  --encoder_type pixel \
  --action_repeat 8 \
  --save_tb --save_model \
  --pre_transform_image_size 100 --image_size 84 \
  --detach_encoder \
  --work_dir /content/drive/MyDrive/curl_runs_detached \
  --agent curl_sac --frame_stack 3 \
  --seed 953115 --critic_lr 1e-3 --actor_lr 1e-3 \
  --eval_freq 10000 --batch_size 128
# Out:
# | eval | S: 0 | ER: 32.3063
# | train | E: 1 | S: 500 | D: 3.7 s | R: 0.0000 | BR: 0.0000 | A_LOSS: 0.0000 | CR_LOSS: 0.0000 | CU_LOSS: 0.0000
# | train | E: 5 | S: 1000 | D: 5.0 s | R: 181.0858 | BR: 0.0000 | A_LOSS: 0.0000 | CR_LOSS: 0.0000 | CU_LOSS: 0.0000
# | train | E: 9 | S: 1500 | D: 12.9 s | R: 61.9767 | BR: 1.1921 | A_LOSS: -2.6535 | CR_LOSS: 3.5293 | CU_LOSS: 3.5951
# | train | E: 13 | S: 2000 | D: 13.2 s | R: 112.1662 | BR: 1.2875 | A_LOSS: -4.3873 | CR_LOSS: 6.4112 | CU_LOSS: 2.4273
# | train | E: 17 | S: 2500 | D: 12.9 s | R: 123.9317 | BR: 1.1083 | A_LOSS: -5.8779 | CR_LOSS: 9.5679 | CU_LOSS: 2.0190
# | train | E: 21 | S: 3000 | D: 13.0 s | R: 116.4547 | BR: 1.2658 | A_LOSS: -8.7777 | CR_LOSS: 16.1660 | CU_LOSS: 1.7088
# | train | E: 25 | S: 3500 | D: 12.9 s | R: 204.1249 | BR: 1.3084 | A_LOSS: -11.2465 | CR_LOSS: 22.9770 | CU_LOSS: 1.4160
# | train | E: 29 | S: 4000 | D: 13.0 s | R: 228.1454 | BR: 1.3407 | A_LOSS: -13.4027 | CR_LOSS: 20.9730 | CU_LOSS: 1.2856
# ...

# %%
# !conda env export -n curl_new --no-builds > /content/curl_new_env_export.yml
# !head -n 30 /content/curl_new_env_export.yml
# Out:
# name: curl_new
# channels:
#   - pytorch
#   - nvidia
#   - conda-forge
# dependencies:
#   - _openmp_mutex=4.5
#   - absl-py=2.4.0
#   - aom=3.5.0
#   - blas=1.0
#   - blosc=1.21.5
#   - brotli=1.0.9
#   - brotli-bin=1.0.9
#   - brotli-python=1.0.9
#   - brunsli=0.1
#   - bzip2=1.0.8
#   - c-blosc2=2.12.0
#   - ca-certificates=2026.1.4
#   - certifi=2026.1.4
#   - cffi=2.0.0
#   - charls=2.4.2
#   - charset-normalizer=3.4.4
#   - cpython=3.10.19
#   - cuda-cudart=12.1.105
#   - cuda-cupti=12.1.105
#   - cuda-libraries=12.1.0
#   - cuda-nvrtc=12.1.105
#   - cuda-nvtx=12.1.105
#   - cuda-opencl=13.1.115
#   - cuda-runtime=12.1.0

# %%
# !conda list -n curl_new --explicit > /content/curl_new_explicit.txt

# %%
# !/usr/local/envs/curl_new/bin/pip freeze > /content/curl_new_pip_freeze.txt

# %%
# !cp /content/curl_new_env_export.yml /content/drive/MyDrive/
# !cp /content/curl_new_explicit.txt /content/drive/MyDrive/
# !cp /content/curl_new_pip_freeze.txt /content/drive/MyDrive/
